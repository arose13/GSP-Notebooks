# %% [markdown]
# # Portfolio Report
# Give the report generator a bunch of symbols to run thru and see the results.
# - Fakefolio: ['GOOG', 'AAPL', 'YHOO', 'MSFT', 'FB']
# - ETFs: ['SPY', 'IBB', 'GLD', 'IWM', 'MDY', 'USO']
# - Dow Jones Industrial Average: ['AAPL', 'AXP', 'BA', 'CAT', 'CSCO', 'CVX', 'DD', 'DIS', 'GE', 'GS', 'HD', 'IBM', 'INTC', 'JNJ', 'JPM', 'KO', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PFE', 'PG', 'TRV', 'UNH', 'V', 'VZ', 'WMT', 'XOM']

# %%
# %matplotlib inline

import warnings
warnings.simplefilter('ignore')

from Helpers.ReportHelper import GenerateReport
from Finance.Portfolio import Portfolio

portfolio = Portfolio(['GOOG', 'AAPL', 'YHOO', 'MSFT', 'FB'], weeks=52*5)
report_generator = GenerateReport(portfolio)

# %% [markdown]
# ## Portfolio Summary
# This is an untraded optimised portfolio as a whole as is.

# %%
report_generator.generate_portfolio_report()
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -0.978600765901
#             Iterations: 5
#             Function evaluations: 35
#             Gradient evaluations: 5
#      fun: -0.97860076590122447
#      jac: array([ -2.91898847e-04,   1.57172317e+00,   2.23625188e+00,
#         -7.18981028e-04,   1.92411244e-04,   0.00000000e+00])
#  message: 'Optimization terminated successfully.'
#     nfev: 35
#      nit: 5
#     njev: 5
#   status: 0
#  success: True
#        x: array([  2.30137661e-01,   4.38187084e-16,   0.00000000e+00,
#          8.88331407e-02,   6.81029199e-01])
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -0.238176533099
#             Iterations: 7
#             Function evaluations: 49
#             Gradient evaluations: 7
#      fun: -0.23817653309911846
#      jac: array([-0.1146555 ,  0.30235954,  0.45697349, -0.08124071, -0.11908826,  0.        ])
# ...

# %% [markdown]
# ## Individual Assets Report
# All the descriptive metrics for each asset in the portfolio

# %%
report_generator.generate_symbol_report()
# Out:
# -----------------------------
# GOOG Report
# -----------------------------
# AAPL Report
# -----------------------------
# YHOO Report
# -----------------------------
# MSFT Report
# -----------------------------
# FB Report

# %% [markdown]
# ## Portfolio Asset Traded Performance
# These are the portfolio's assets algorithm's results on the out of sample set data for each asset in the portfolio

# %%
report_generator.generate_algorithm_performance_report()
# Out:
# -----------------------------
# GOOG Algorithm Performance
# Traded Sharpe Ratio: 3.821980212239322
# Max Drawdown: -0.05802160662624335
# Transaction Costs: $26
# ($1 commission)
#
# -----------------------------
# AAPL Algorithm Performance
# Traded Sharpe Ratio: 4.442029762448375
# Max Drawdown: -0.04134254342276273
# Transaction Costs: $26
# ($1 commission)
#
# -----------------------------
# YHOO Algorithm Performance
# Traded Sharpe Ratio: 4.509596999377646
# Max Drawdown: -0.06035222628492735
# Transaction Costs: $19
# ($1 commission)
#
# -----------------------------
# MSFT Algorithm Performance
# Traded Sharpe Ratio: 4.120940550369424
# Max Drawdown: -0.038870853222031654
# Transaction Costs: $25
# ($1 commission)
#
# -----------------------------
# FB Algorithm Performance
# Traded Sharpe Ratio: 3.1598978221117835
# Max Drawdown: -0.0619773790914801
# Transaction Costs: $33
# ($1 commission)

# %% [markdown]
# ## Traded Portfolio Performance
# The test set results are combined into an equally weighted portfolio for analysis.

# %%
# Combine traded assets into a portfolio and benchmark it's performance
report_generator.generate_traded_portfolio_performance_report()
# Out:
# -----------------------------
# Summary for Combined Account
# Total Transaction Cost $129
# Sharpe Ratio 7.123120840772477
# Sortino Ratio 1.424472602941365
# Max Drawdowns -0.022941843660068854
